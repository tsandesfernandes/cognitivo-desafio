# %%
from pyspark.sql.types import * 
from pyspark.sql.functions import *
import json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs.mkdirs("/cognitivo/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: True</div>

# %%
#apos criar o diretorio, copei os arquivos do .zip que joguei na pasta local
#dbfs cp . dbfs:/cognitivo/
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs ls /cognitivo/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/cognitivo/config/</td><td>config/</td><td>0</td></tr><tr><td>dbfs:/cognitivo/data/</td><td>data/</td><td>0</td></tr><tr><td>dbfs:/cognitivo/requirements/</td><td>requirements/</td><td>0</td></tr><tr><td>dbfs:/cognitivo/scripts/</td><td>scripts/</td><td>0</td></tr></tbody></table></div>

# %%
users_file = '/cognitivo/data/input/users/load.csv'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
users_df = sqlContext.read.format('com.databricks.spark.csv').options(header='true', inferschema='true').load(users_file)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
users_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+--------------------+--------------------+---------------+--------------------+---+--------------------+--------------------+
#  id|                name|               email|          phone|             address|age|         create_date|         update_date|
# +---+--------------------+--------------------+---------------+--------------------+---+--------------------+--------------------+
#   1|david.lynch@cogni...|         David Lynch|(11) 99999-9997|Mulholland Drive,...| 72|2018-03-03 18:47:...|2018-03-03 18:47:...|
#   1|david.lynch@cogni...|         David Lynch|(11) 99999-9998|Mulholland Drive,...| 72|2018-03-03 18:47:...|2018-04-14 17:09:...|
#   2|sherlock.holmes@c...|     Sherlock Holmes|(11) 94815-1623|221B Baker Street...| 34|2018-04-21 20:21:...|2018-04-21 20:21:...|
#   3|spongebob.squarep...|Spongebob Squarep...|(11) 91234-5678|124 Conch Street,...| 13|2018-05-19 04:07:...|2018-05-19 04:07:...|
#   1|david.lynch@cogni...|         David Lynch|(11) 99999-9999|Mulholland Drive,...| 72|2018-03-03 18:47:...|2018-05-23 10:13:...|
#   3|spongebob.squarep...|Spongebob Squarep...|(11) 98765-4321|122 Conch Street,...| 13|2018-05-19 04:07:...|2018-05-19 05:08:...|
# +---+--------------------+--------------------+---------------+--------------------+---+--------------------+--------------------+
#
# </div>

# %%
users_df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- id: integer (nullable = true)
# -- name: string (nullable = true)
# -- email: string (nullable = true)
# -- phone: string (nullable = true)
# -- address: string (nullable = true)
# -- age: integer (nullable = true)
# -- create_date: timestamp (nullable = true)
# -- update_date: timestamp (nullable = true)
#
# </div>

# %%
users_df = users_df.select(col('id'), col('name').alias('email'), col('email').alias('name'), col('phone'), col('address'), col('age'), col('create_date'), col('update_date'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(users_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>email</th><th>name</th><th>phone</th><th>address</th><th>age</th><th>create_date</th><th>update_date</th></tr></thead><tbody><tr><td>1</td><td>david.lynch@cognitivo.ai</td><td>David Lynch</td><td>(11) 99999-9997</td><td>Mulholland Drive, Los Angeles, CA, US</td><td>72</td><td>2018-03-03T18:47:01.954+0000</td><td>2018-03-03T18:47:01.954+0000</td></tr><tr><td>1</td><td>david.lynch@cognitivo.ai</td><td>David Lynch</td><td>(11) 99999-9998</td><td>Mulholland Drive, Los Angeles, CA, US</td><td>72</td><td>2018-03-03T18:47:01.954+0000</td><td>2018-04-14T17:09:48.558+0000</td></tr><tr><td>2</td><td>sherlock.holmes@cognitivo.ai</td><td>Sherlock Holmes</td><td>(11) 94815-1623</td><td>221B Baker Street, London, UK</td><td>34</td><td>2018-04-21T20:21:24.364+0000</td><td>2018-04-21T20:21:24.364+0000</td></tr><tr><td>3</td><td>spongebob.squarepants@cognitivo.ai</td><td>Spongebob Squarepants</td><td>(11) 91234-5678</td><td>124 Conch Street, Bikini Bottom, Pacific Ocean</td><td>13</td><td>2018-05-19T04:07:06.854+0000</td><td>2018-05-19T04:07:06.854+0000</td></tr><tr><td>1</td><td>david.lynch@cognitivo.ai</td><td>David Lynch</td><td>(11) 99999-9999</td><td>Mulholland Drive, Los Angeles, CA, US</td><td>72</td><td>2018-03-03T18:47:01.954+0000</td><td>2018-05-23T10:13:59.594+0000</td></tr><tr><td>3</td><td>spongebob.squarepants@cognitivo.ai</td><td>Spongebob Squarepants</td><td>(11) 98765-4321</td><td>122 Conch Street, Bikini Bottom, Pacific Ocean</td><td>13</td><td>2018-05-19T04:07:06.854+0000</td><td>2018-05-19T05:08:07.964+0000</td></tr></tbody></table></div>

# %%
#2. Deduplicação dos dados convertidos: No conjunto de dados convertidos haverão múltiplas entradas para um mesmo registro, variando apenas os valores de alguns dos campos entre elas. Será necessário realizar um processo de deduplicação destes dados, a fim de apenas manter a última entrada de cada registro, usando como referência o id para identificação dos registros duplicados e a data de atualização (update_date) para definição do registro mais recente;
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
users_df_reference = users_df.groupBy('id', ).agg({'update_date':  'max'} ).withColumnRenamed('max(update_date)', "update_date")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
users_df_reference.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+--------------------+
#  id|         update_date|
# +---+--------------------+
#   1|2018-05-23 10:13:...|
#   3|2018-05-19 05:08:...|
#   2|2018-04-21 20:21:...|
# +---+--------------------+
#
# </div>

# %%
condicao = [users_df_reference['id'] == users_df['id'], users_df_reference['update_date'] == users_df['update_date']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
result_2_df = users_df.join(users_df_reference, on=condicao)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(result_2_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>email</th><th>name</th><th>phone</th><th>address</th><th>age</th><th>create_date</th><th>update_date</th><th>id</th><th>update_date</th></tr></thead><tbody><tr><td>2</td><td>sherlock.holmes@cognitivo.ai</td><td>Sherlock Holmes</td><td>(11) 94815-1623</td><td>221B Baker Street, London, UK</td><td>34</td><td>2018-04-21T20:21:24.364+0000</td><td>2018-04-21T20:21:24.364+0000</td><td>2</td><td>2018-04-21T20:21:24.364+0000</td></tr><tr><td>1</td><td>david.lynch@cognitivo.ai</td><td>David Lynch</td><td>(11) 99999-9999</td><td>Mulholland Drive, Los Angeles, CA, US</td><td>72</td><td>2018-03-03T18:47:01.954+0000</td><td>2018-05-23T10:13:59.594+0000</td><td>1</td><td>2018-05-23T10:13:59.594+0000</td></tr><tr><td>3</td><td>spongebob.squarepants@cognitivo.ai</td><td>Spongebob Squarepants</td><td>(11) 98765-4321</td><td>122 Conch Street, Bikini Bottom, Pacific Ocean</td><td>13</td><td>2018-05-19T04:07:06.854+0000</td><td>2018-05-19T05:08:07.964+0000</td><td>3</td><td>2018-05-19T05:08:07.964+0000</td></tr></tbody></table></div>

# %%
#3. Conversão do tipo dos dados deduplicados: No diretório config haverá um arquivo JSON de configuração (types_mapping.json), contendo os nomes dos campos e os respectivos tipos desejados de output. Utilizando esse arquivo como input, realizar um processo de conversão dos tipos dos campos descritos, no conjunto de dados deduplicados;
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
types_mapping = '/dbfs/cognitivo/config/types_mapping.json'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
with open(types_mapping, "r") as json_file:
  types_dict = json.load(json_file)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(types_dict)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#39;age&#39;: &#39;integer&#39;, &#39;create_date&#39;: &#39;timestamp&#39;, &#39;update_date&#39;: &#39;timestamp&#39;}
# </div>

# %%
users_df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- id: integer (nullable = true)
# -- email: string (nullable = true)
# -- name: string (nullable = true)
# -- phone: string (nullable = true)
# -- address: string (nullable = true)
# -- age: integer (nullable = true)
# -- create_date: timestamp (nullable = true)
# -- update_date: timestamp (nullable = true)
#
# </div>

# %%
types_dict['id'] = 'integer'
types_dict['email'] = 'string'
types_dict['name'] = 'string'
types_dict['phone'] = 'string'
types_dict['address'] = 'string'
types_dict['create_date'] = 'timestamp'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(types_dict)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#39;age&#39;: &#39;integer&#39;, &#39;create_date&#39;: &#39;timestamp&#39;, &#39;update_date&#39;: &#39;timestamp&#39;, &#39;id&#39;: &#39;integer&#39;, &#39;email&#39;: &#39;string&#39;, &#39;name&#39;: &#39;string&#39;, &#39;phone&#39;: &#39;string&#39;, &#39;address&#39;: &#39;string&#39;}
# </div>

# %%
for col_name in users_df.columns:
  if col_name in types_dict.keys():
    result3_df = users_df.withColumn(col_name, users_df[col_name].cast(types_dict[col_name]))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(result3_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>email</th><th>name</th><th>phone</th><th>address</th><th>age</th><th>create_date</th><th>update_date</th></tr></thead><tbody><tr><td>1</td><td>david.lynch@cognitivo.ai</td><td>David Lynch</td><td>(11) 99999-9997</td><td>Mulholland Drive, Los Angeles, CA, US</td><td>72</td><td>2018-03-03T18:47:01.954+0000</td><td>2018-03-03T18:47:01.954+0000</td></tr><tr><td>1</td><td>david.lynch@cognitivo.ai</td><td>David Lynch</td><td>(11) 99999-9998</td><td>Mulholland Drive, Los Angeles, CA, US</td><td>72</td><td>2018-03-03T18:47:01.954+0000</td><td>2018-04-14T17:09:48.558+0000</td></tr><tr><td>2</td><td>sherlock.holmes@cognitivo.ai</td><td>Sherlock Holmes</td><td>(11) 94815-1623</td><td>221B Baker Street, London, UK</td><td>34</td><td>2018-04-21T20:21:24.364+0000</td><td>2018-04-21T20:21:24.364+0000</td></tr><tr><td>3</td><td>spongebob.squarepants@cognitivo.ai</td><td>Spongebob Squarepants</td><td>(11) 91234-5678</td><td>124 Conch Street, Bikini Bottom, Pacific Ocean</td><td>13</td><td>2018-05-19T04:07:06.854+0000</td><td>2018-05-19T04:07:06.854+0000</td></tr><tr><td>1</td><td>david.lynch@cognitivo.ai</td><td>David Lynch</td><td>(11) 99999-9999</td><td>Mulholland Drive, Los Angeles, CA, US</td><td>72</td><td>2018-03-03T18:47:01.954+0000</td><td>2018-05-23T10:13:59.594+0000</td></tr><tr><td>3</td><td>spongebob.squarepants@cognitivo.ai</td><td>Spongebob Squarepants</td><td>(11) 98765-4321</td><td>122 Conch Street, Bikini Bottom, Pacific Ocean</td><td>13</td><td>2018-05-19T04:07:06.854+0000</td><td>2018-05-19T05:08:07.964+0000</td></tr></tbody></table></div>

# %%
result3_df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- id: integer (nullable = true)
# -- email: string (nullable = true)
# -- name: string (nullable = true)
# -- phone: string (nullable = true)
# -- address: string (nullable = true)
# -- age: integer (nullable = true)
# -- create_date: timestamp (nullable = true)
# -- update_date: timestamp (nullable = true)
#
# </div>

# %%
#1. Conversão do formato dos arquivos: Converter o arquivo CSV presente no diretório data/input/users/load.csv, para um formato colunar de alta performance de leitura de sua escolha. Justificar brevemente a escolha do formato;
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
users_df.write.parquet('/cognitivo/data/output/output.parquet')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs ls /cognitivo/data/output/output.parquet
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/cognitivo/data/output/output.parquet/_SUCCESS</td><td>_SUCCESS</td><td>0</td></tr><tr><td>dbfs:/cognitivo/data/output/output.parquet/_committed_7591499190595469551</td><td>_committed_7591499190595469551</td><td>125</td></tr><tr><td>dbfs:/cognitivo/data/output/output.parquet/_started_7591499190595469551</td><td>_started_7591499190595469551</td><td>0</td></tr><tr><td>dbfs:/cognitivo/data/output/output.parquet/part-00000-tid-7591499190595469551-76ba2699-5ceb-4b4d-968a-4bc5b39e5a4b-2035-1-c000.snappy.parquet</td><td>part-00000-tid-7591499190595469551-76ba2699-5ceb-4b4d-968a-4bc5b39e5a4b-2035-1-c000.snappy.parquet</td><td>2773</td></tr></tbody></table></div>

# %%
parquet_df = sqlContext.read.parquet('/cognitivo/data/output/output.parquet')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(parquet_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>email</th><th>name</th><th>phone</th><th>address</th><th>age</th><th>create_date</th><th>update_date</th></tr></thead><tbody><tr><td>1</td><td>david.lynch@cognitivo.ai</td><td>David Lynch</td><td>(11) 99999-9997</td><td>Mulholland Drive, Los Angeles, CA, US</td><td>72</td><td>2018-03-03T18:47:01.954+0000</td><td>2018-03-03T18:47:01.954+0000</td></tr><tr><td>1</td><td>david.lynch@cognitivo.ai</td><td>David Lynch</td><td>(11) 99999-9998</td><td>Mulholland Drive, Los Angeles, CA, US</td><td>72</td><td>2018-03-03T18:47:01.954+0000</td><td>2018-04-14T17:09:48.558+0000</td></tr><tr><td>2</td><td>sherlock.holmes@cognitivo.ai</td><td>Sherlock Holmes</td><td>(11) 94815-1623</td><td>221B Baker Street, London, UK</td><td>34</td><td>2018-04-21T20:21:24.364+0000</td><td>2018-04-21T20:21:24.364+0000</td></tr><tr><td>3</td><td>spongebob.squarepants@cognitivo.ai</td><td>Spongebob Squarepants</td><td>(11) 91234-5678</td><td>124 Conch Street, Bikini Bottom, Pacific Ocean</td><td>13</td><td>2018-05-19T04:07:06.854+0000</td><td>2018-05-19T04:07:06.854+0000</td></tr><tr><td>1</td><td>david.lynch@cognitivo.ai</td><td>David Lynch</td><td>(11) 99999-9999</td><td>Mulholland Drive, Los Angeles, CA, US</td><td>72</td><td>2018-03-03T18:47:01.954+0000</td><td>2018-05-23T10:13:59.594+0000</td></tr><tr><td>3</td><td>spongebob.squarepants@cognitivo.ai</td><td>Spongebob Squarepants</td><td>(11) 98765-4321</td><td>122 Conch Street, Bikini Bottom, Pacific Ocean</td><td>13</td><td>2018-05-19T04:07:06.854+0000</td><td>2018-05-19T05:08:07.964+0000</td></tr></tbody></table></div>

# %%
#Utilizei o parquet, porque, primeiramente é colunar e segundo é suportado por varios sistemas de processamento
